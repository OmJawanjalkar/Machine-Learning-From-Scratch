# %% [markdown]
# # Top Interview Questions on Ridge, Lasso, Elastic Net, Cross-Validation & Hyperparameter Tuning
#
# These are the most frequently asked interview questions for **Data Scientist**, **Machine Learning Engineer**, and **Data Analyst** roles.
#
# ---
#
# # Ridge, Lasso & Elastic Net Regression
#
# ## 1. What is Regularization? Why is it needed?
#
# * What is Regularization?
# * Why do we use Regularization?
# * How does it reduce overfitting?
#
# ---
#
# ## 2. What is Ridge Regression?
#
# * Explain Ridge Regression.
# * What is L2 Regularization?
# * When should Ridge Regression be used?
# * What are its advantages and disadvantages?
#
# ---
#
# ## 3. What is Lasso Regression?
#
# * Explain Lasso Regression.
# * What is L1 Regularization?
# * When should Lasso Regression be used?
# * What are its advantages and disadvantages?
#
# ---
#
# ## 4. What is Elastic Net Regression?
#
# * Explain Elastic Net Regression.
# * Why was Elastic Net introduced?
# * When should Elastic Net be preferred over Ridge and Lasso?
#
# ---
#
# ## 5. What is the difference between Ridge, Lasso, and Elastic Net?
#
# Explain the following:
#
# * Penalty used
# * Feature Selection
# * Coefficient Shrinkage
# * Multicollinearity
# * Best use cases
#
# ---
#
# ## 6. What is the difference between L1 and L2 Regularization?
#
# Explain:
#
# * Mathematical intuition
# * Effect on coefficients
# * Feature selection
# * Computational differences
#
# ---
#
# ## 7. Why does Lasso perform Feature Selection?
#
# * Why do some coefficients become exactly zero?
# * How does L1 Regularization work?
#
# ---
#
# ## 8. Why doesn't Ridge Regression remove features?
#
# * Why are coefficients reduced but not eliminated?
# * What happens to irrelevant features?
#
# ---
#
# ## 9. When should you choose Ridge over Lasso?
#
# Explain different scenarios.
#
# Example:
#
# * Highly correlated features
# * High-dimensional datasets
# * Feature selection not required
#
# ---
#
# ## 10. When should you choose Lasso over Ridge?
#
# Explain different scenarios.
#
# Example:
#
# * Many irrelevant features
# * Need for model interpretability
# * Automatic feature selection
#
# ---
#
# ## 11. What are the advantages and disadvantages of Elastic Net?
#
# Explain:
#
# * Advantages
# * Disadvantages
# * Real-world applications
#
# ---
#
# ## 12. Why is Feature Scaling important for Ridge and Lasso?
#
# * Why should data be standardized?
# * What happens if features have different scales?
#
# ---
#
# # Cross-Validation
#
# ## 13. What is Cross-Validation?
#
# * What is Cross-Validation?
# * Why do we use it?
# * How does it improve model evaluation?
#
# ---
#
# ## 14. Why is Cross-Validation better than a Train-Test Split?
#
# Explain:
#
# * Reliable performance estimation
# * Reduced bias
# * Better utilization of data
#
# ---
#
# ## 15. Explain K-Fold Cross-Validation.
#
# * How does K-Fold work?
# * Why is K=5 or K=10 commonly used?
# * Advantages and disadvantages
#
# ---
#
# ## 16. What is Stratified K-Fold Cross-Validation?
#
# * Why is it used?
# * Why is it important for classification?
# * When should it be preferred?
#
# ---
#
# ## 17. What is Leave-One-Out Cross-Validation (LOOCV)?
#
# * How does LOOCV work?
# * Advantages
# * Disadvantages
# * When should it be used?
#
# ---
#
# ## 18. What is Time Series Cross-Validation?
#
# * Why can't we use K-Fold for time series?
# * How does Time Series CV work?
# * Give real-world examples.
#
# ---
#
# ## 19. What are the advantages and disadvantages of Cross-Validation?
#
# Discuss:
#
# * Better model evaluation
# * Computational cost
# * Bias-Variance tradeoff
#
# ---
#
# # Hyperparameter Tuning
#
# ## 20. What is Hyperparameter Tuning?
#
# * What are Hyperparameters?
# * Difference between Parameters and Hyperparameters.
# * Why is tuning required?
#
# ---
#
# ## 21. What is Grid Search?
#
# * Explain Grid Search.
# * Advantages
# * Disadvantages
# * Use cases
#
# ---
#
# ## 22. What is Random Search?
#
# * Explain Random Search.
# * Why is it faster?
# * Advantages
# * Disadvantages
#
# ---
#
# ## 23. What is the difference between Grid Search and Random Search?
#
# Compare:
#
# * Search strategy
# * Speed
# * Computational cost
# * Best use cases
#
# ---
#
# ## 24. What is RidgeCV?
#
# * What is RidgeCV?
# * How does it automatically select the best alpha?
# * Advantages over Ridge Regression.
#
# ---
#
# ## 25. What is LassoCV?
#
# * Explain LassoCV.
# * How does it perform feature selection automatically?
# * Why is Cross-Validation used?
#
# ---
#
# ## 26. What is ElasticNetCV?
#
# * Explain ElasticNetCV.
# * What are alpha and l1_ratio?
# * How are they selected automatically?
#
# ---
#
# ## 27. What is the role of the Alpha parameter?
#
# * What does alpha control?
# * What happens if alpha is very small?
# * What happens if alpha is very large?
#
# ---
#
# ## 28. What is l1_ratio in Elastic Net?
#
# * What does l1_ratio represent?
# * How does it balance Ridge and Lasso?
#
# ---
#
# ## 29. Why do we use Cross-Validation during Hyperparameter Tuning?
#
# Explain:
#
# * Fair model comparison
# * Better generalization
# * Preventing overfitting
#
# ---
#
# ## 30. Explain the complete workflow of Regularized Linear Regression.
#
# A complete workflow should include:
#
# 1. Understand the business problem
# 2. Data Collection
# 3. Exploratory Data Analysis (EDA)
# 4. Data Cleaning
# 5. Handle Missing Values
# 6. Feature Engineering
# 7. Feature Scaling
# 8. Train-Test Split
# 9. Train Linear Regression
# 10. Check for Overfitting
# 11. Apply Ridge/Lasso/Elastic Net
# 12. Perform Cross-Validation
# 13. Tune Hyperparameters
# 14. Compare Models
# 15. Select the Best Model
# 16. Evaluate Performance
# 17. Deploy the Model
#
# ---
#
# # Bonus Interview Questions
#
# 1. Why does Ridge Regression reduce variance?
#
# 2. Why does Lasso Regression produce sparse models?
#
# 3. Can Ridge Regression perform Feature Selection?
#
# 4. Why is Elastic Net preferred when features are highly correlated?
#
# 5. What happens if alpha = 0 in Ridge Regression?
#
# 6. What happens if alpha is extremely large?
#
# 7. What is the Bias-Variance Tradeoff?
#
# 8. How does Regularization reduce Overfitting?
#
# 9. Why should categorical variables be encoded before applying Ridge or Lasso?
#
# 10. Can Ridge or Lasso be used for Classification?
#
# 11. Why should Feature Scaling be performed before Regularization?
#
# 12. Which is better: Grid Search or Random Search?
#
# 13. What is Data Leakage in Cross-Validation?
#
# 14. Why shouldn't we shuffle Time Series data?
#
# 15. Explain a real-world project where you would use Ridge, Lasso, or Elastic Net Regression.
#
# ---
#
# # Interview Preparation Tip
#
# If you can confidently answer these **30 core questions** and **15 bonus questions**, along with their mathematical intuition, practical applications, Scikit-learn implementation, and real-world examples, you will be well prepared for interviews covering **Regularization, Cross-Validation, and Hyperparameter Tuning**.
